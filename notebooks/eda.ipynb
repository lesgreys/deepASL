# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from skimage import io, color, filters
from skimage.transform import resize, rotate
from skimage.color import rgb2gray
from sklearn.cluster import KMeans
from src.main import get_imlist
# Out:
#   File "<ipython-input-65-2b425884697b>", line 12
#     from ../src.main.py import get_imlist
#            ^
# SyntaxError: invalid syntax

# %%
a_sample = io.imread('~/Desktop/sample.png')
lr_gray = rgb2gray(a_sample)

# %%
plt.imshow(lr_gray)

# %%
lr_gray.sha
lr_gray_ravel = np.ravel(lr_gray)

# %%
plt.hist(lr_gray_ravel)
# Out:
# (array([ 27661.,  77488.,  44494.,  30595.,  68955.,  53640.,  24232.,
#          10834.,    617., 233932.]),
#  array([0.18431373, 0.26588235, 0.34745098, 0.42901961, 0.51058824,
#         0.59215686, 0.67372549, 0.75529412, 0.83686275, 0.91843137,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
X = a_sample.reshape(-1,3)
# Out:
# (763264, 3)

# %%
clf = KMeans(n_clusters=3).fit(X)
clf.cluster_centers_
# Out:
# array([[115.70951026, 115.73248978, 254.99563775],
#        [251.09898461, 251.16273244, 250.07222683],
#        [160.88854485, 160.81053201, 114.73200097]])

# %%
clf.labels_.shape
# Out:
# (763264,)

# %%
labels = set(clf.labels_)
print(labels)
# Out:
# {0, 1, 2}

# %%
sobel_me = filters.sobel(lr_gray)
io.imshow(sobel_me)

# %%
from skimage.feature._canny import canny
canny_me = canny(lr_gray, sigma=1)

# %%
io.imshow(canny_me)
